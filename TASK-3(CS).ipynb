# %% [markdown]
# 1.   JENISHA ANGEL B
# 2.   CODSOFT
# 3.   TASK-3
# 4.   CREDIT CARD FRAUD DETECTION

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Load the data

# %%
credit_card_data=pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 37717  39076  1.117749 -1.544665 -0.145357 -1.307482 -1.392833 -0.630833
# 37718  39076  0.758729 -0.483875  0.125488  1.449159 -0.639231 -0.805011
# 37719  39076 -0.474907  0.835804  0.075878 -1.251283  2.492736  3.385419
# 37720  39077 -2.682780 -2.028562  1.745223 -1.157952 -0.143692 -0.807503
# 37721  39077  1.106292 -0.525727  0.926440  0.817696 -1.122177 -0.062703
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 37717 -0.563659 -0.038716 -2.173892  ... -0.334155 -1.108220  0.070461
# 37718  0.406994 -0.221212  0.068777  ...  0.210712  0.063091 -0.316636
# 37719  0.169507  0.934749 -0.584224  ... -0.270398 -0.866353 -0.085720
# 37720 -1.154141  0.436917 -0.293442  ...  0.353396  0.968145 -0.776459
# 37721       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37722 entries, 0 to 37721
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    37722 non-null  int64
#  1   V1      37722 non-null  float64
#  2   V2      37722 non-null  float64
#  3   V3      37722 non-null  float64
#  4   V4      37722 non-null  float64
#  5   V5      37722 non-null  float64
#  6   V6      37722 non-null  float64
#  7   V7      37721 non-null  float64
#  8   V8      37721 non-null  float64
#  9   V9      37721 non-null  float64
#  10  V10     37721 non-null  float64
#  11  V11     37721 non-null  float64
#  12  V12     37721 non-null  float64
#  13  V13     37721 non-null  float64
#  14  V14     37721 non-null  float64
#  15  V15     37721 non-null  float64
#  16  V16     37721 non-null  float64
#  17  V17     37721 non-null  float64
#  18  V18     37721 non-null  float64
#  19  V19     37721 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# Handling Null values

# %%
credit_card_data['V7'].fillna(credit_card_data['V7'].mode()[0],inplace=True)
credit_card_data['V8'].fillna(credit_card_data['V8'].mode()[0],inplace=True)
credit_card_data['V9'].fillna(credit_card_data['V9'].mode()[0],inplace=True)
credit_card_data['V10'].fillna(credit_card_data['V10'].mode()[0],inplace=True)
credit_card_data['V11'].fillna(credit_card_data['V11'].mode()[0],inplace=True)
credit_card_data['V12'].fillna(credit_card_data['V12'].mode()[0],inplace=True)
credit_card_data['V13'].fillna(credit_card_data['V13'].mode()[0],inplace=True)
credit_card_data['V14'].fillna(credit_card_data['V14'].mode()[0],inplace=True)
credit_card_data['V15'].fillna(credit_card_data['V15'].mode()[0],inplace=True)
credit_card_data['V16'].fillna(credit_card_data['V16'].mode()[0],inplace=True)
credit_card_data['V17'].fillna(credit_card_data['V17'].mode()[0],inplace=True)
credit_card_data['V18'].fillna(credit_card_data['V18'].mode()[0],inplace=True)
credit_card_data['V19'].fillna(credit_card_data['V19'].mode()[0],inplace=True)
credit_card_data['V20'].fillna(credit_card_data['V20'].mode()[0],inplace=True)
credit_card_data['V21'].fillna(credit_card_data['V21'].mode()[0],inplace=True)
credit_card_data['V22'].fillna(credit_card_data['V22'].mode()[0],inplace=True)
credit_card_data['V23'].fillna(credit_card_data['V23'].mode()[0],inplace=True)
credit_card_data['V24'].fillna(credit_card_data['V24'].mode()[0],inplace=True)
credit_card_data['V25'].fillna(credit_card_data['V25'].mode()[0],inplace=True)
credit_card_data['V26'].fillna(credit_card_data['V26'].mode()[0],inplace=True)
credit_card_data['V27'].fillna(credit_card_data['V27'].mode()[0],inplace=True)
credit_card_data['V28'].fillna(credit_card_data['V28'].mode()[0],inplace=True)
credit_card_data['Amount'].fillna(credit_card_data['Amount'].mode()[0],inplace=True)
credit_card_data['Class'].fillna(credit_card_data['Class'].mode()[0],inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transactions & fradulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    37619
# 1.0      103
# Name: Class, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %% [markdown]
# 0.0-->Normal Transaction
#
# 1.0-->fradulent Transaction

# %%
# separating the data for analysis
legit=credit_card_data[credit_card_data.Class==0.0]
fraud=credit_card_data[credit_card_data.Class==1.0]

# %%
print(legit.shape)
# Out:
# (37619, 31)

# %%
print(fraud.shape)
# Out:
# (103, 31)

# %% [markdown]
# Statistical measures of the data

# %%
legit.Amount.describe()
# Out:
# count    37619.000000
# mean        86.015151
# std        232.955255
# min          0.000000
# 25%          7.300000
# 50%         22.880000
# 75%         77.660000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    24778.592892 -0.186752  0.044181   0.749336  0.176767 -0.209593
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6       V7        V8        V9  ...       V20       V21  \
# Class                                         ...
# 0.0    0.105908 -0.09297  0.025707  0.243333  ...  0.044686 -0.032044
# 1.0   -2.306085 -7.74310  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25      V26       V27       V28  \
# Class
# 0.0   -0.111594 -0.040412  0.007186  0.135741  0.02136  0.007037  0.003658
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.18039  0.822304  0.102481
#
#           Amount
# Class
# 0.0    86.015151
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distributions of normal transactions and fraudulent transactions

# %%
# Number of Fraudulent Transaction -->103
legit_sample = legit.sample(n=103)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 16589  27956  0.968801 -0.085018  0.300873  1.471164 -0.208497 -0.133167
# 34892  37872  1.268617 -0.080302  0.172915 -0.013128 -0.136541 -0.019055
# 2673    2213 -0.242858  0.668693  1.679167  1.098383  0.470291  0.001612
# 9598   14430  1.184266 -0.043157  0.744515  0.073656 -0.347332  0.170345
# 23814  32932 -1.354750 -0.877343  1.242614 -2.285772 -1.077222 -1.023139
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 16589  0.232459 -0.066166  0.213146  ... -0.035254 -0.074444 -0.156725
# 34892 -0.135780 -0.010602  0.219861  ... -0.247396 -0.534383 -0.086727
# 2673   0.889940 -0.332754  0.249789  ... -0.078690  0.253596 -0.172603
# 9598  -0.565054  0.054825  1.362705  ...  0.001271  0.306848 -0.049050
# 23814 -0.782867  0.471242 -2.204397  ... -0.221372 -0.784031  0.170145
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 30442 -6.805053  2.928356 -4.917130  ...  1.691042  0.920021 -0.151104
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473  0.614573  0.028521
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888 -0.845753  0.190674
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641 -0.962960 -0.110045
# 33276 -5.283435  0.131619  0.658176  ... -0.734308 -0.599926 -4.908301
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    103
# 1.0    103
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    26769.834951 -0.533299 -0.006036   0.712869  0.192264 -0.108168
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.035791 -0.111071  0.170505  0.529752  ...  0.114479 -0.084018
# 1.0   -2.306085 -7.743100  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.176073 -0.113309 -0.111468  0.163613 -0.030205  0.020796 -0.051481
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0.0    76.036408
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features and Targets

# %%
x=new_dataset.drop(columns='Class',axis=1)
y=new_dataset['Class']

# %%
print(x)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 16589  27956  0.968801 -0.085018  0.300873  1.471164 -0.208497 -0.133167
# 34892  37872  1.268617 -0.080302  0.172915 -0.013128 -0.136541 -0.019055
# 2673    2213 -0.242858  0.668693  1.679167  1.098383  0.470291  0.001612
# 9598   14430  1.184266 -0.043157  0.744515  0.073656 -0.347332  0.170345
# 23814  32932 -1.354750 -0.877343  1.242614 -2.285772 -1.077222 -1.023139
# ...      ...       ...       ...       ...       ...       ...       ...
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(y)
# Out:
# 16589    0.0
# 34892    0.0
# 2673     0.0
# 9598     0.0
# 23814    0.0
#         ...
# 30442    1.0
# 30473    1.0
# 30496    1.0
# 31002    1.0
# 33276    1.0
# Name: Class, Length: 206, dtype: float64

# %% [markdown]
# Splitting the data into training data and Testing data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (206, 30) (164, 30) (42, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model=LogisticRegression()

# %%
# training the Logistic Regression Model with training Data
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Accuracy Score

# %%
# for training data
x_train_prediction=model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)

# %%
print("Accuracy of the Training Data: ",training_data_accuracy)
# Out:
# Accuracy of the Training Data:  0.9695121951219512

# %%
# for testing data
x_test_prediction=model.predict(x_test)
testing_data_accuracy=accuracy_score(x_test_prediction,y_test)

# %%
print("Accuracy of the Testing Data: ",testing_data_accuracy)
# Out:
# Accuracy of the Testing Data:  0.9523809523809523

# %% [markdown]
# training data and testing data are similar
